# %%
# !pip install qrcode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import qrcode
Text_p = qrcode.make("ನದಿಯಂತೆ ಹರಿಯು... ದಾರಿಯಲ್ಲಿ ಅಡೆತಡೆಗಳಿದ್ದರೂ ನಿಲ್ಲಬೇಡ; ಕೊನೆಗೆ ಸಮುದ್ರವೇ ನಿನ್ನನ್ನು ಕಾಯುತ್ತಿದೆ. 🌊")
Text_p.save("pari.jpg")

# %%
ls
# Out:
# pari.jpg  sample_data/

# %%
from PIL import Image
img = Image.open("pari.jpg")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=690x690>

# %%
import qrcode
Text_p = qrcode.make("Two hearts💞, one promise, and a⏳ lifetime to cherish. May your marriage be blessed with endless love, peace, and happiness in every season of life❣️")
Text_p.save("pari.jpg")

# %%
ls
# Out:
# pari.jpg  sample_data/

# %%
from PIL import Image
img = Image.open("pari.jpg")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=610x610>

# %%
flie = files.download("pari.jpg")

# %%
import qrcode
Text_p = qrcode.make("https://www.vecteezy.com/free-photos/cute-baby-dog")
Text_p.save("pari.jpg")

# %%
ls
# Out:
#  2pra.jpg  ' nanu '/   pari.jpg   QR_Code.png   sample_data/

# %%
from PIL import Image
img = Image.open("pari.jpg")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=410x410>

# %%
flie = files.download("pari.jpg")
